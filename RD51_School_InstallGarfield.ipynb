# %% [markdown]
# <a href="https://colab.research.google.com/github/pietverwilligen/Schools/blob/master/RD51_School_InstallGarfield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is a trial for Garfield and ROOT installation to prepare for the RD51 Simulation school exercises. It is based on Josh E. Renner's Google [COLAB example](https://colab.research.google.com/github/jerenner/garfieldfem/blob/master/garfield_FEM_install.ipynb#scrollTo=58UUGU_DOJzt). Trial made 2023-09-25.

# %% [markdown]
# # Preparing the environment for running Garfield++ on Colab
# Preliminary information for people new to Jupiter Notebooks & google COLAB:
# - The use of an exclamation mark is to run commands of the underlying operation system;

# %%
# !lscpu
# Out:
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         46 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  2
#   On-line CPU(s) list:   0,1
# Vendor ID:               GenuineIntel
#   Model name:            Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:          6
#     Model:               79
#     Thread(s) per core:  2
#     Core(s) per socket:  1
#     Socket(s):           1
#     Stepping:            0
#     BogoMIPS:            4399.99
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy nonstop_tsc cpuid tsc_known_freq pni pclmulqdq sss
#                          e3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes
# ...

# %%
# !free -m -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       627Mi       8.4Gi       1.0Mi       3.7Gi        11Gi
# Swap:             0B          0B          0B

# %% [markdown]
#   What c++ and fortran compiler we have in our hands? And do we have cmake installed, which helps in compiling code?

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.2 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.2 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !gfortran --version
# Out:
# GNU Fortran (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !cmake --version
# Out:
# cmake version 3.27.4
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %% [markdown]
#  And finally let's verify what is our current working directory and what is inside:

# %%
# !pwd
# Out:
# /content

# %%
# !ls -lrth
# Out:
# total 4.0K
# drwxr-xr-x 1 root root 4.0K Sep 21 13:49 sample_data

# %% [markdown]
# # ROOT installation

# %% [markdown]
# We will follow the instructions for the installation from the [ROOT webpage](https://root.cern/install/#build-from-source). For the installation of ROOT we need the libXpm and Xpm headers, therefore we will install these first:

# %%
# !apt-get install libxpm-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libxpm-dev
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 90.3 kB of archives.
# After this operation, 217 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxpm-dev amd64 1:3.5.12-1ubuntu0.22.04.1 [90.3 kB]
# Fetched 90.3 kB in 0s (277 kB/s)
# Selecting previously unselected package libxpm-dev:amd64.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../libxpm-dev_1%3a3.5.12-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.1) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.1) ...

# %%
# !git clone --branch latest-stable --depth=1 https://github.com/root-project/root.git root_src
# Out:
# Cloning into 'root_src'...
# remote: Enumerating objects: 25014, done.
# remote: Counting objects: 100% (25014/25014), done.
# remote: Compressing objects: 100% (21674/21674), done.
# remote: Total 25014 (delta 3843), reused 11872 (delta 2780), pack-reused 0
# Receiving objects: 100% (25014/25014), 181.95 MiB | 13.25 MiB/s, done.
# Resolving deltas: 100% (3843/3843), done.
# Updating files: 100% (22979/22979), done.

# %%
# !mkdir root_build root_install

# %%
# !pwd
# Out:
# /content

# %%
# !ls -lrth
# Out:
# total 16K
# drwxr-xr-x  1 root root 4.0K Sep 21 13:49 sample_data
# drwxr-xr-x 42 root root 4.0K Sep 25 09:12 root_src
# drwxr-xr-x  2 root root 4.0K Sep 25 09:12 root_build
# drwxr-xr-x  2 root root 4.0K Sep 25 09:12 root_install

# %%
cd root_build
# Out:
# /content/root_build

# %%
# !pwd
# Out:
# /content/root_build

# %%
# !cmake -DCMAKE_INSTALL_PREFIX=../root_install ../root_src # && check cmake configuration output for warnings or errors
# Out:
# -- Detected ROOT_VERSION 6.28.06
# -- Checking internet connectivity
# -- Checking internet connectivity - found
# -- Looking for Python
# -- Could NOT find Python2 (missing: Python2_EXECUTABLE Python2_INCLUDE_DIRS Python2_LIBRARIES Python2_NumPy_INCLUDE_DIRS Interpreter Development NumPy Development.Module Development.Embed)
#     Reason given by package:
#         Interpreter: Wrong major version for the interpreter "/usr/local/bin/python"
#
# -- Found GCC. Major version 11, minor version 4
# -- ROOT Platform: linux
# -- ROOT Compiler: GNU 11.4.0
# -- ROOT Processor: x86_64
# -- ROOT Architecture: linuxx8664gcc
# -- Build Type: 'Release' (flags = '-O3 -DNDEBUG')
# -- Compiler Flags:  -std=c++17 -Wno-implicit-fallthrough -Wno-noexcept-type -pipe  -Wshadow -Wall -W -Woverloaded-virtual -fsigned-char -pthread -O3 -DNDEBUG
# -- ROOT default compression algorithm: zlib
# CMake Deprecation Warning at cmake/modules/RootBuildOptions.cmake:434 (message):
# ...

# %%
# !cmake --build . -- install -j2 # if you have 2 cores available for compilation
# Out:
# Streaming output truncated to the last 5000 lines.
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TGeometry.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/THYPE.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/THelix.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TMarker3DBox.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TMaterial.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TMixture.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TNode.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TNodeDiv.h to /content/root_build/include
# [ 13%] Copying header /content/root_src/graf3d/g3d/inc/TPARA.h to /content/root_build/include
# ...
